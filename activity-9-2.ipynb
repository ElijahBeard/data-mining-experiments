# %%
import pandas as pd
import numpy as np
import math
data = pd.read_csv("mutationc.csv",index_col=0)
np.random.seed(52)

# %% [markdown]
# ### Phi Computation

# %%
idx = data.index.astype(str)
C_mask = data.index.to_series().str.match(r"^C\d+$")
NC_mask = data.index.to_series().str.match(r"^NC\d+$")

def entropy(P_C_t,P_NC_t):
    ans = 0.0
    if P_C_t > 0:
        ans -= P_C_t * math.log2(P_C_t)
    if P_NC_t > 0:
        ans -= P_NC_t * math.log2(P_NC_t)
    return ans

def information_gain(group:pd.DataFrame):
    n = group.shape[0]
    is_C = C_mask.loc[group.index]
    is_NC = NC_mask.loc[group.index]
    # calc that can be done for group
    n_t_C = int(is_C.sum())
    n_t_NC = int(is_NC.sum())
    P_C_t = n_t_C / n
    P_NC_t = n_t_NC / n
    H_t = entropy(P_C_t, P_NC_t)
    rows = []
    for feature in group.columns:
        col = group[feature]
        left_mask = (col == 1)
        right_mask = ~left_mask
        n_tL = int(left_mask.sum())
        n_tR = n - n_tL
        n_tL_C  = int((left_mask  & is_C).sum())
        n_tL_NC = int((left_mask  & is_NC).sum())
        n_tR_C  = int((right_mask & is_C).sum())
        n_tR_NC = int((right_mask & is_NC).sum())
        P_L = n_tL / n
        P_R = n_tR / n
        P_C_tL  = n_tL_C  / n_tL if n_tL != 0 else 0
        P_NC_tL = n_tL_NC / n_tL if n_tL != 0 else 0
        P_C_tR  = n_tR_C  / n_tR if n_tR != 0 else 0
        P_NC_tR = n_tR_NC / n_tR if n_tR != 0 else 0
        H_st = P_L * entropy(P_C_tL, P_NC_tL) + P_R * entropy(P_C_tR, P_NC_tR)
        gain = H_t - H_st
        rows.append((feature, gain))
        
    return pd.DataFrame(rows, columns=["feature", "gain(s)"]).set_index("feature")

# %% [markdown]
# ### Random Forest Generation

# %%
class tree:
    def __init__(self,F=None,alpha=None,beta=None,leaves=None,oob=None):
        self.F = F
        self.alpha = alpha
        self.beta = beta
        self.leaves = leaves
        self.oob = oob

    def classify(self,sample):
        if sample[self.F] == 1:
            if sample[self.alpha] == 1:
                return self.leaves["A1"]
            else:
                return self.leaves["A2"]
        else:
            if sample[self.beta] == 1:
                return self.leaves["B1"]
            else:
                return self.leaves["B2"]
            
def leaf_majority(leaf:pd.DataFrame):
    leaf_idx = leaf.index.to_series().replace(r'^C\d+$','1',regex=True).replace(r'^NC\d+$','0',regex=True).astype(int)
    if leaf_idx.mean() > 0.5:
        return 1 # majority cancer
    else:
        return 0 # majority noncancer

def create_tree(group:pd.DataFrame):
    bootstrap = group.sample(n=len(group),replace=True)
    oob = group.loc[~group.index.isin(bootstrap.index)]
    k = math.ceil(math.sqrt(group.shape[1]))
    F = information_gain(bootstrap).sample(n=k)["gain(s)"].idxmax()

    groupA = bootstrap[bootstrap[F] == 1]
    groupB = bootstrap[bootstrap[F] == 0]

    alpha = information_gain(groupA).sample(n=k)["gain(s)"].idxmax()
    beta = information_gain(groupB).sample(n=k)["gain(s)"].idxmax()

    ln_a1  = groupA[groupA[alpha] == 1]
    ln_a2 = (groupA[groupA[alpha] == 0])
    if len(ln_a1) == 0: ln_a1 = groupA
    if len(ln_a2) == 0: ln_a2 = groupA

    ln_b1 = groupB[groupB[beta] == 1]
    ln_b2 = groupB[groupB[beta] == 0]
    if len(ln_b1) == 0: ln_b1 = groupB
    if len(ln_b2) == 0: ln_b2 = groupB

    leaves = {"A1":leaf_majority(ln_a1),"A2":leaf_majority(ln_a2),
              "B1":leaf_majority(ln_b1),"B2":leaf_majority(ln_b2)}

    return tree(F,alpha,beta,leaves,oob)

# %%
print("Forest Generation")
NUM_TREES = 25
forest = []
oob_sum = 0.0
for trial in range(1,NUM_TREES+1):
    gen_tree = create_tree(data)
    print(f" Tree {trial} --\n\tRoot:{gen_tree.F}\n\tAlpha:{gen_tree.alpha}\n\tBeta:{gen_tree.beta}\n\tOOB Size:{len(gen_tree.oob)}\n")
    oob_sum += len(gen_tree.oob)
    forest.append(gen_tree)
print(f"OOB Average: {oob_sum / NUM_TREES}")

def forest_classifier(idx,sample,forest):
    votes = []
    for t in forest:
        votes.append(t.classify(sample))
    votes_for_C = sum(votes)
    votes_for_NC = len(votes) - votes_for_C
    if votes_for_C > votes_for_NC:
        label = "C"
        value = 1
    else:
        label = "NC"
        value = 0
    return pd.Series({"idx":idx,"label":label, "value":value,
            "C_votes":votes_for_C,"NC_Votes":votes_for_NC})
# Out:
# Forest Generation
#  Tree 1 --
# 	Root:ARID1A_GRCh37_1:27105931-27105931_Frame-Shift-Del_DEL_G-G--
# 	Alpha:SLC27A2_GRCh37_15:50515214-50515214_Missense-Mutation_SNP_G-G-A
# 	Beta:CCDC39_GRCh37_3:180332568-180332568_3'UTR_DEL_T-T--
# 	OOB Size:73
#
#  Tree 2 --
# 	Root:PHACTR1_GRCh37_6:13206135-13206135_Frame-Shift-Del_DEL_G-G--
# 	Alpha:ZNF142_GRCh37_2:219508084-219508084_Frame-Shift-Del_DEL_C-C--
# 	Beta:KRAS_GRCh37_12:25380275-25380275_Missense-Mutation_SNP_T-T-G
# 	OOB Size:79
#
#  Tree 3 --
# 	Root:PCDH19_GRCh37_X:99662505-99662505_Frame-Shift-Del_DEL_G-G--
# 	Alpha:APC_GRCh37_5:112151204-112151204_Nonsense-Mutation_SNP_C-C-T
# 	Beta:RAB28_GRCh37_4:13485808-13485808_5'UTR_DEL_G-G--
# 	OOB Size:77
#
#  Tree 4 --
# 	Root:CNTNAP5_GRCh37_2:125672808-125672808_3'UTR_SNP_C-C-T
# 	Alpha:PLCB3_GRCh37_11:64032517-64032517_Frame-Shift-Del_DEL_C-C--
# 	Beta:SALL1_GRCh37_16:51172618-51172618_Missense-Mutation_SNP_G-G-A
# 	OOB Size:75
#
#  Tree 5 --
# 	Root:OR6K2_GRCh37_1:158669532-158669532_Frame-Shift-Del_DEL_T-T--
# 	Alpha:GJA4_GRCh37_1:35260157-35260157_Missense-Mutation_SNP_G-G-A
# 	Beta:HSP90AB1_GRCh37_6:44221447-44221447_3'UTR_DEL_T-T--
# 	OOB Size:71
#
#  Tree 6 --
# 	Root:MLLT1_GRCh37_19:6213976-6213976_Frame-Shift-Del_DEL_G-G--
# 	Alpha:ANKRD19P_GRCh37_9:95572023-95572023_RNA_DEL_G-G--
# 	Beta:MYB_GRCh37_6:135518338-135518338_Intron_DEL_A-A--
# 	OOB Size:80
#
#  Tree 7 --
# 	Root:KCNMA1_GRCh37_10:78646919-78646919_3'UTR_SNP_A-A-G
# 	Alpha:SLC7A10_GRCh37_19:33703794-33703794_Frame-Shift-Del_DEL_G-G--
# 	Beta:TMEM232_GRCh37_5:109940905-109940905_Frame-Shift-Del_DEL_T-T--
# 	OOB Size:69
#
#  Tree 8 --
# 	Root:SLC8A2_GRCh37_19:47969003-47969003_Frame-Shift-Del_DEL_A-A--
# 	Alpha:TP53_GRCh37_17:7579591-7579591_Splice-Site_SNP_C-C-T_C-C-G
# 	Beta:TET1_GRCh37_10:70404809-70404809_Frame-Shift-Del_DEL_A-A--
# 	OOB Size:68
#
#  Tree 9 --
# 	Root:ZBTB20_GRCh37_3:114058003-114058003_Frame-Shift-Del_DEL_G-G--
# 	Alpha:TTC40_GRCh37_10:134699453-134699453_Silent_SNP_G-G-A
# 	Beta:TP53_GRCh37_17:7577548-7577548_Missense-Mutation_SNP_C-C-T
# 	OOB Size:76
#
#  Tree 10 --
# 	Root:XYLT2_GRCh37_17:48433967-48433967_Frame-Shift-Del_DEL_C-C--
# 	Alpha:RTL1_GRCh37_14:101347507-101347507_Frame-Shift-Del_DEL_G-G--
# 	Beta:KIF13A_GRCh37_6:17837308-17837308_Frame-Shift-Del_DEL_C-C--
# 	OOB Size:76
#
#  Tree 11 --
# 	Root:WDR66_GRCh37_12:122437640-122437640_Missense-Mutation_SNP_G-G-A
# 	Alpha:MDGA2_GRCh37_14:47530771-47530771_Frame-Shift-Del_DEL_T-T--
# 	Beta:DEFB136_GRCh37_8:11831592-11831592_Missense-Mutation_SNP_G-G-A
# 	OOB Size:73
#
#  Tree 12 --
# 	Root:PGM5_GRCh37_9:70993145-70993145_Missense-Mutation_SNP_A-A-G
# 	Alpha:KCNB2_GRCh37_8:73850023-73850023_Silent_SNP_C-C-T
# 	Beta:ZDHHC8_GRCh37_22:20130522-20130522_Frame-Shift-Del_DEL_C-C--
# 	OOB Size:73
#
#  Tree 13 --
# 	Root:ZBTB20_GRCh37_3:114058003-114058003_Frame-Shift-Del_DEL_G-G--
# 	Alpha:ARID1A_GRCh37_1:27106804-27106804_Frame-Shift-Del_DEL_C-C--
# 	Beta:CLDND2_GRCh37_19:51870355-51870355_3'UTR_DEL_A-A--
# 	OOB Size:77
#
#  Tree 14 --
# 	Root:PHACTR1_GRCh37_6:13287429-13287429_Intron_SNP_T-T-A
# 	Alpha:ZNF263_GRCh37_16:3336043-3336043_Silent_SNP_C-C-T
# 	Beta:TECTA_GRCh37_11:121032949-121032949_Silent_SNP_C-C-T
# 	OOB Size:71
#
#  Tree 15 --
# 	Root:DOCK3_GRCh37_3:51417604-51417604_Frame-Shift-Del_DEL_C-C--
# 	Alpha:EPHX2_GRCh37_8:27364393-27364393_Frame-Shift-Del_DEL_T-T--
# 	Beta:TLL1_GRCh37_4:167022090-167022090_3'UTR_SNP_T-T-A
# 	OOB Size:73
#
#  Tree 16 --
# 	Root:RAB28_GRCh37_4:13485808-13485808_5'UTR_DEL_G-G--
# 	Alpha:HMX3_GRCh37_10:124895627-124895627_Frame-Shift-Del_DEL_C-C--
# 	Beta:PHF21A_GRCh37_11:45955607-45955607_Frame-Shift-Del_DEL_G-G--
# 	OOB Size:78
#
#  Tree 17 --
# 	Root:PTCHD3_GRCh37_10:27702951-27702951_Frame-Shift-Del_DEL_G-G--
# 	Alpha:ABR_GRCh37_17:909374-909374_Frame-Shift-Del_DEL_G-G--
# 	Beta:TICAM1_GRCh37_19:4816465-4816465_Frame-Shift-Del_DEL_G-G--
# 	OOB Size:80
#
#  Tree 18 --
# 	Root:CAND1_GRCh37_12:67706721-67706721_3'UTR_DEL_T-T--
# 	Alpha:GRIA2_GRCh37_4:158281222-158281222_Missense-Mutation_SNP_G-G-A
# 	Beta:KIF2B_GRCh37_17:51900501-51900501_Missense-Mutation_SNP_G-G-A
# 	OOB Size:78
#
#  Tree 19 --
# 	Root:SLC25A42_GRCh37_19:19221753-19221753_3'UTR_DEL_G-G--
# 	Alpha:SLC25A33_GRCh37_1:9642611-9642611_3'UTR_DEL_T-T--
# 	Beta:HNRNPL_GRCh37_19:39330959-39330959_Frame-Shift-Del_DEL_G-G--
# 	OOB Size:73
#
#  Tree 20 --
# 	Root:ALPK2_GRCh37_18:56246440-56246440_Frame-Shift-Del_DEL_T-T--
# 	Alpha:ALX4_GRCh37_11:44286624-44286624_Frame-Shift-Del_DEL_G-G--
# 	Beta:DRD5_GRCh37_4:9785349-9785349_3'UTR_SNP_G-G-C
# 	OOB Size:68
#
#  Tree 21 --
# 	Root:RAB28_GRCh37_4:13485808-13485808_5'UTR_DEL_G-G--
# 	Alpha:MGST2_GRCh37_4:140624683-140624683_Frame-Shift-Del_DEL_A-A--
# 	Beta:GRM7_GRCh37_3:7456772-7456772_Missense-Mutation_SNP_G-G-A
# 	OOB Size:70
#
#  Tree 22 --
# 	Root:DOCK3_GRCh37_3:51417604-51417604_Frame-Shift-Del_DEL_C-C--
# 	Alpha:PHYH_GRCh37_10:13344024-13344024_5'Flank_DEL_T-T--
# 	Beta:UBQLN2_GRCh37_X:56591874-56591874_Frame-Shift-Del_DEL_C-C--
# 	OOB Size:65
#
#  Tree 23 --
# 	Root:CD93_GRCh37_20:23066469-23066469_Frame-Shift-Del_DEL_C-C--
# 	Alpha:ATP5EP2_GRCh37_13:28519580-28519580_3'UTR_SNP_G-G-A
# 	Beta:C20orf85_GRCh37_20:56735727-56735727_Frame-Shift-Del_DEL_C-C--
# 	OOB Size:74
#
#  Tree 24 --
# 	Root:PAPPA2_GRCh37_1:176525981-176525981_Missense-Mutation_SNP_G-G-A
# 	Alpha:MAP7D3_GRCh37_X:135314194-135314194_Frame-Shift-Del_DEL_G-G--
# 	Beta:TSPYL4_GRCh37_6:116574704-116574704_Frame-Shift-Del_DEL_T-T--
# 	OOB Size:75
#
#  Tree 25 --
# 	Root:KMT2D_GRCh37_12:49434492-49434492_Frame-Shift-Del_DEL_G-G--
# 	Alpha:TP53_GRCh37_17:7577141-7577141_Missense-Mutation_SNP_C-C-T_C-C-A
# 	Beta:TRIM24_GRCh37_7:138279285-138279285_3'Flank_DEL_A-A--
# 	OOB Size:74
#
# OOB Average: 73.84

# %% [markdown]
# ## Classifying Set of Samples

# %%
samples = ["C1","C10","C15","NC5","NC15"]
for sample in samples:
    result = forest_classifier(sample,data.loc[sample],forest)
    print(sample,"-> predicted",result.label)
# Out:
# C1 -> predicted C
# C10 -> predicted C
# C15 -> predicted C
# NC5 -> predicted NC
# NC15 -> predicted NC

# %% [markdown]
# ## Classifying Out-Of-Bag Samples

# %%
samples = forest[0].oob.index.to_list()
# print("OOB Classifications--")
oob = forest[0].oob
oob_classification = []
for sample in samples:
    result = forest_classifier(sample,oob.loc[sample],forest)
    # print(sample,"-> predicted ",result.label)
    oob_classification.append(result)

# %%
predicted = pd.Series([s.value for s in oob_classification],index=samples)
actual = oob.index.to_series().replace(r'^C\d+$','1',regex=True).replace(r'^NC\d+$','0',regex=True).astype(int)

# %%
def compute_metrics(actual:pd.Series,predicted:pd.Series):
    TP = ((actual == 1) & (predicted == 1)).sum(axis=0)
    FP = ((actual == 0) & (predicted == 1)).sum(axis=0)
    FN = ((actual == 1) & (predicted == 0)).sum(axis=0)
    TN = ((actual == 0) & (predicted == 0)).sum(axis=0)
    Accuracy = (TP + TN) / (TP + TN + FP + FN)
    Sensitivity = TP / (TP + FN)
    Specificity = TN / (TN + FP)
    Precision = TP / (TP + FP)
    Miss_rate = FN / (TP + FN)
    False_discovery_rate = FP / (TP + FP)
    False_omission_rate = FN / (FN + TN)
    metrics = pd.DataFrame({"Accuracy":Accuracy,"Sensitivity":Sensitivity,
                            "Specificity":Specificity,"Precision":Precision,
                            "Miss Rate":Miss_rate,"False Discovery Rate":False_discovery_rate,
                            "False Omission Rate":False_omission_rate},index=[0])
    return metrics
results = compute_metrics(actual,predicted)

# %%
results
# Out:
#    Accuracy  Sensitivity  Specificity  Precision  Miss Rate  \
# 0  0.643836     0.351351     0.944444   0.866667   0.648649
#
#    False Discovery Rate  False Omission Rate
# 0              0.133333             0.413793
